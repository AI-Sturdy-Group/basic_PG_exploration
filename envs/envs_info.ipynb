# %%
# %matplotlib inline

# %%
import os
import sys
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

PROJECT_DIR = "C:\\projects\\basic_PG_exploration"
sys.path.append(PROJECT_DIR)

from simple_continuous import SimpleContinuousEnvironment

# %%
step_target=np.array([4.0])
max_reward_step=1
steps=1
env = SimpleContinuousEnvironment(step_target, max_reward_step, steps)

# %%
env.get_environment_state()
# Out:
# array([1])

# %%
actions = np.arange(-1, 1.01, 0.01)
rewards = [env.environment_step(action)[1] for action in actions]

# %%
rewards = [env.environment_step(action)[1] for action in actions]

# %%
plt.plot(actions, rewards)
plt.grid()
plt.xlabel("actions")
plt.ylabel("rewards")
# Out:
# Text(0, 0.5, 'rewards')
