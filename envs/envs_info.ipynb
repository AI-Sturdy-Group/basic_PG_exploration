# %%
# %matplotlib inline

# %%
import os
import sys
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import tensorflow_probability as tfp


PROJECT_DIR = "C:\\projects\\basic_PG_exploration"
sys.path.append(PROJECT_DIR)

from simple_continuous import BaseSimpleContinuousEnvironment

# %%
step_target=0.5
steps=1
env = BaseSimpleContinuousEnvironment()

# %%
env.get_environment_state()
# Out:
# array([[1.]])

# %%
actions = np.arange(-1, 1.01, 0.01)
rewards = [env.environment_step(action)[1] for action in actions]

# %%
plt.plot(actions, rewards)
plt.grid()
plt.xlabel("actions")
plt.ylabel("rewards")
# Out:
# Text(0, 0.5, 'rewards')

# %%
prob_actions = np.arange(-6, 6.01, 0.01)
probs = tfp.distributions.Normal(0., 1.0).prob(prob_actions)
plt.plot(prob_actions, probs)
plt.grid()
plt.xlabel("actions")
plt.ylabel("probs")
# Out:
# Text(0, 0.5, 'probs')

# %%
env = BaseSimpleContinuousEnvironment(reward_function="max_range")
env.get_environment_state()
# Out:
# array([[1.]])

# %%
actions = np.arange(-1, 1.01, 0.01)
rewards = [env.environment_step(action)[1] for action in actions]
plt.plot(actions, rewards)
plt.grid()
plt.xlabel("actions")
plt.ylabel("rewards")
# Out:
# Text(0, 0.5, 'rewards')
